# %% [markdown]
# --- Day 4: Secure Container ---
# You arrive at the Venus fuel depot only to discover it's protected by a password. The Elves had written the password on a sticky note, but someone threw it out.
#
# However, they do remember a few key facts about the password:
#
# It is a six-digit number.
# The value is within the range given in your puzzle input.
# Two adjacent digits are the same (like 22 in 122345).
# Going from left to right, the digits never decrease; they only ever increase or stay the same (like 111123 or 135679).
# Other than the range rule, the following are true:
#
# 111111 meets these criteria (double 11, never decreases).
# 223450 does not meet these criteria (decreasing pair of digits 50).
# 123789 does not meet these criteria (no double).
# How many different passwords within the range given in your puzzle input meet these criteria?
#
# Your puzzle input is 240920-789857.

# %%
import numpy as np

# %%
input1 = 240920
input2 = 789857
valid_passwords = [x for x in range(input1,input2+1)]

# %%
len(valid_passwords)
# Out:
# 548938

# %%
valid_passwords
# Out:
# [240920,
#  240921,
#  240922,
#  240923,
#  240924,
#  240925,
#  240926,
#  240927,
#  240928,
#  240929,
#  240930,
#  240931,
#  240932,
#  240933,
#  240934,
#  240935,
#  240936,
#  240937,
#  240938,
#  240939,
#  240940,
#  240941,
#  240942,
#  240943,
#  240944,
#  240945,
#  240946,
#  240947,
#  240948,
#  240949,
#  240950,
#  240951,
#  240952,
#  240953,
#  240954,
#  240955,
#  240956,
#  240957,
#  240958,
#  240959,
#  240960,
#  240961,
#  240962,
#  240963,
#  240964,
#  240965,
#  240966,
#  240967,
#  240968,
#  240969,
#  240970,
#  240971,
#  240972,
#  240973,
#  240974,
#  240975,
#  240976,
#  240977,
#  240978,
#  240979,
#  240980,
#  240981,
#  240982,
#  240983,
#  240984,
#  240985,
#  240986,
#  240987,
#  240988,
#  240989,
#  240990,
#  240991,
#  240992,
#  240993,
#  240994,
#  240995,
#  240996,
#  240997,
#  240998,
#  240999,
#  241000,
#  241001,
#  241002,
#  241003,
#  241004,
#  241005,
#  241006,
#  241007,
#  241008,
#  241009,
# ...

# %%
solution =[]
for num in valid_passwords:
    dgt_1 = np.floor(num / 1000000 * 10)
    dgt_2 = np.floor(num / 100000 * 10) - np.floor(num/100000) * 10
    dgt_3 = np.floor(num / 10000 * 10) - np.floor(num/10000) * 10
    dgt_4 = np.floor(num / 1000 * 10) - np.floor(num/1000) * 10
    dgt_5 = np.floor(num / 100 * 10) - np.floor(num/100) * 10
    dgt_6 = np.floor(num / 10 * 10) - np.floor(num/10) * 10
    if ((dgt_1 <= dgt_2 and 
         dgt_2 <= dgt_3 and
         dgt_3 <= dgt_4 and
         dgt_4 <= dgt_5 and
         dgt_5 <= dgt_6) and
        (dgt_1 == dgt_2 or
          dgt_2 == dgt_3 or 
          dgt_3 == dgt_4 or 
          dgt_4 == dgt_5 or 
          dgt_5 == dgt_6)):
        solution.append(num)

# %%
len(solution)
# Out:
# 1154

# %%
# solution2 = []
# solution_final = []
# str_valid_passwords = [str(num) for num in valid_passwords]
# set_passwords = [set(valid) for valid in str_valid_passwords]


# for i in range (0, len(str_valid_passwords)-1):
    #if len(str_valid_passwords[i]) != len(set_passwords[i]):
        #solution2.append(str_valid_passwords[i])

# %%
#( (int(str_valid_passwords[0]) <= (int(str_valid_passwords[0]) and 
        #(int(str_valid_passwords[0]) <= (int(solution2[0]) and
         #(int(str_valid_passwords[0]) <= (int(solution2[0]) and
         #(int(str_valid_passwords[0]) <= (int(solution2[0]) and
         #(int(str_valid_passwords[0]) <= (int(solution2[0])))

# %% [markdown]
# An Elf just remembered one more important detail: the two adjacent matching digits are not part of a larger group of matching digits.
#
# Given this additional criterion, but still ignoring the range rule, the following are now true:
#
# 112233 meets these criteria because the digits never decrease and all repeated digits are exactly two digits long.
# 123444 no longer meets the criteria (the repeated 44 is part of a larger group of 444).
# 111122 meets the criteria (even though 1 is repeated more than twice, it still contains a double 22).
# How many different passwords within the range given in your puzzle input meet all of the criteria?

# %%
nemjok = []
for num in solution:
    dgt_1 = np.floor(num / 1000000 * 10)
    dgt_2 = np.floor(num / 100000 * 10) - np.floor(num/100000) * 10
    dgt_3 = np.floor(num / 10000 * 10) - np.floor(num/10000) * 10
    dgt_4 = np.floor(num / 1000 * 10) - np.floor(num/1000) * 10
    dgt_5 = np.floor(num / 100 * 10) - np.floor(num/100) * 10
    dgt_6 = np.floor(num / 10 * 10) - np.floor(num/10) * 10
    if ((dgt_1 == dgt_2 == dgt_3 and dgt_4 != dgt_5 != dgt_6) or
        (dgt_1 == dgt_2 == dgt_3 and dgt_4 == dgt_5 == dgt_6) or
        (dgt_2 == dgt_3 == dgt_4 and dgt_5 != dgt_6 ) or
        (dgt_3 == dgt_4 == dgt_5 and dgt_1 != dgt_2) or
        (dgt_4 == dgt_5 == dgt_6 and dgt_1 != dgt_2 != dgt_3) or
        (dgt_2 == dgt_3 == dgt_4 == dgt_5) or
        (dgt_1 == dgt_2 == dgt_3 == dgt_4 and dgt_5 != dgt_6) or
        (dgt_1 != dgt_2 and dgt_3 == dgt_4 == dgt_5 == dgt_6)
        ):
        nemjok.append(num)

# %%
len(nemjok)
# Out:
# 404

# %%
len(solution)-len(nemjok)
# Out:
# 750
