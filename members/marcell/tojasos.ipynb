# %%
from jkg_evaluators import eggdrop_100floor_2egg

# %%
def my_solution(breaks):

    lowest_possible_floor = 15
    highest_possible_floor = 100
    
    while not breaks(lowest_possible_floor):

        if highest_possible_floor - lowest_possible_floor > 71:
            memory = lowest_possible_floor
            lowest_possible_floor = lowest_possible_floor + 15
        
        #Ez a harom if igy nem jo. Mivel kulonallo elagazasok, ezert egymas utan lefuttatja oket a fuggvenyed.
        #Ez ugye azt jelentheti, hogy atugorhatsz szinteket. Ha pl nem tort el a 15-ös szinten,
        # akkor a kulonbseg nagyobb mint 71, ezert hozzaad a lowest-hez 15-öt, majd megnézi, hogy a kulonbseg 71 es 30 kozott van e.
        #Mivel a lowest mar 30 ezert ez igaz lesz, tehat hozzad 10-et es a kovetkezo iteracioban 30 helyett 40re nezi meg, hogy eltorik e.
        #Ehelyett hasznalhattad volna az if-elif-else felosztast, ilyenkor ugye sorban ertekeli ki a felteteleket es ha az egyik elagazasba belep,
        #akkor a tobbit mar ki sem ertekeli.
        if 71 > highest_possible_floor - lowest_possible_floor >= 30:
            memory = lowest_possible_floor
            lowest_possible_floor = lowest_possible_floor + 10

        if 30 >= highest_possible_floor - lowest_possible_floor:
            memory = lowest_possible_floor
            lowest_possible_floor = lowest_possible_floor + 5
    
    lowest_possible_floor = memory
    #Ha a 15. emeleten mmar eltorik, akkor rogton odaugrik, hogy lowest_possible_floor = memory,
    #viszont mivel a memory valtozod csak akkor letezik, ha egyszer is lefutott a while alatti resz, ezert 1-15 kozott hibat dob a programod.
    #Szerintem ez a ket hiba megmagyarazza

    while not breaks(lowest_possible_floor):
        lowest_possible_floor = lowest_possible_floor +1


    return lowest_possible_floor - 1

#Ez nem lenne rossz megoldas, ha kezeltel volna egyket hibat, ezt javitsd ki ha lehet.

# %%
eggdrop_100floor_2egg.evaluate(my_solution)
# Out:
# - success rate: 63/101 (62.0%)
# - error count: 15
# - best performance: 3
# - worst performance: 16
# - mean performance: 8.69767441860465
#
#
#  BAD SOLUTION at:
#  {'egg_count': 2, 'floor_count': 100, 'max_floor': 15}
#
#
#  BAD SOLUTION at:
#  {'egg_count': 2, 'floor_count': 100, 'max_floor': 16}
#
#
#  BAD SOLUTION at:
#  {'egg_count': 2, 'floor_count': 100, 'max_floor': 17}
#
#
#  BAD SOLUTION at:
#  {'egg_count': 2, 'floor_count': 100, 'max_floor': 18}
#
#
#  BAD SOLUTION at:
#  {'egg_count': 2, 'floor_count': 100, 'max_floor': 19}
#
#
#  BAD SOLUTION at:
#  {'egg_count': 2, 'floor_count': 100, 'max_floor': 20}
#
#
#  BAD SOLUTION at:
#  {'egg_count': 2, 'floor_count': 100, 'max_floor': 21}
#
#
#  BAD SOLUTION at:
#  {'egg_count': 2, 'floor_count': 100, 'max_floor': 22}
#
#
#  BAD SOLUTION at:
#  {'egg_count': 2, 'floor_count': 100, 'max_floor': 23}
#
#
#  BAD SOLUTION at:
#  {'egg_count': 2, 'floor_count': 100, 'max_floor': 24}
#
#
#  ERROR at:
# ...
