# %%
with open("day_6_input.txt") as f:
    content = f.read()
    content = content.replace("\n", ".")
    content = content.replace(")", ".")
    content = content.split(".")
#print(content)
#rawmap = open("day_6_input.txt").read().replace("\n", ".").replace(")", ".").split(".")

# %%
composite_list = [content[x:x+2] for x in range(0, len(content),2)]
#print(composite_list)

# %%
total = composite_list
total_1 = set(content)

elso_elemek = []
masodik_elemek = []
sorrend = []

for elso in total:
    elso_elemek.append(elso[0])
    masodik_elemek.append(elso[1])
print(elso_elemek)
#print(masodik_elemek)
# Out:
# ['3TK', 'M33', 'SRG', '9J7', 'BV1', 'NQZ', 'P37', 'J8J', 'RRN', '5DG', 'RP6', '4DY', 'Z2H', 'LPL', 'NDC', '7QT', 'DYB', 'JKN', '9NY', 'TVC', 'V85', '65S', 'KY1', 'M12', '37X', 'J1J', '22J', 'CLV', 'DVN', 'X92', 'L93', 'VPY', 'TXC', '583', 'Z3F', 'NYX', 'VZJ', '8MT', '513', 'FDV', '3XT', '7XG', 'DKJ', 'DJ7', 'YTP', 'YPQ', 'HCC', 'LPH', 'V4N', 'X5T', '3FW', 'M79', 'PXL', '7QC', 'GLV', 'JX6', '325', '8HF', 'GVY', 'H7K', 'LW1', '36S', 'PV1', '8RV', '1MH', '9LV', 'BFM', 'QD4', '156', 'CC1', 'RSH', 'P4M', 'LHN', 'XBW', '4R9', 'B8Y', 'QFV', 'WT9', 'WK9', 'J71', '7S3', '8T4', '3SV', '9K7', 'HFB', 'Y15', '1C6', '9RP', 'VB9', 'Z2R', 'R76', 'T7Q', 'KJB', 'YSZ', 'K9D', 'Y5B', 'KNL', 'QPC', 'CJC', 'C2M', 'Y3C', 'KHV', 'YXZ', 'B25', '9MV', 'XH7', '2GJ', 'RZN', 'S4Y', 'CDR', '9QH', 'S1M', 'ZFN', '5C8', '58V', '467', 'FGB', 'SHF', 'PQH', '4CK', 'JYK', '8NW', '85X', 'FK8', '5YX', 'JV3', 'ML2', 'C79', 'H9W', 'LKN', '1SW', 'MJG', 'HH7', '4B9', 'CFY', 'KHS', 'KV4', '6LC', 'LFN', 'KG7', '5FT', 'K3J', 'KZL', 'B1R', 'CJV', '1FH', 'Z83', 'BFF', 'NC1', 'QRK', 'WJ2', '9M2', '33X', 'G78', 'CPH', 'T69', 'DGS', 'VS2', 'LLB', 'RF9', 'JN6', 'TC6', 'TX9', 'QPV', '39Q', 'QFL', '23D', 'CD9', 'W54', '9C1', 'CYB', '5DS', '7YL', 'FB4', 'TQR', 'W5L', 'TWN', '1DN', 'QCC', '38B', 'R8F', 'XM2', 'RQW', '2R5', '2BY', 'B99', '2BP', 'TV5', '9TH', 'ZWD', 'HGV', 'VJ6', 'KV4', 'RWZ', '6X9', 'VNS', 'P5Z', '9QP', 'JKC', 'V35', 'ZTW', 'VJQ', 'TLY', 'ZDC', 'VXN', 'XT9', 'BTL', '3J4', 'Z35', '
MG', 'GWT', 'H8W', 'G6Z', 'TQ1', 'DXT', 'GWR', '4LL', 'NKH', 'KW9', 'NZN', '9K8', 'GZ4', '83V', 'RMS', 'GBN', '2SK', '1MR', 'LVR', 'YSG', '13R', '88T', '33F', 'ZHF', 'GB3', '1L1', 'SKL', 'NZ2', 'Q7H', 'N42', 'RLW', 'NDJ', 'QXG', 'H3H', 'MTP', 'ZTL', '87R', 'F34', 'W45', 'CQ9', 'RSR', 'BD6', 'XBV', '5C8', 'Y96', 'JVW', 'QQG', 'RMB', '6ZX', 'Q6H', '3NY', 'JDN', '8PF', '6NH', 'LQY', 'Q3S', '554', 'TTW', 'WZF', '284', 'SZS', 'GGX', 'BZD', '6ZJ', '144', '3TD', 'FD3', 'V89', 'CDR', 'XZM', 'V1W', 'MF5', 'PW3', 'HTK', '23J', '1CT', 'Z9H', 'D8G', 'QW8', '94F', '7TM', 'SV9', '2JQ', 'T9H', '9SX', 'Y7L', '9PR', 'FMK', 'X1T', '7YC', 'QN1', 'PD9', 'F7C', 'SGY', '21L', 'PZ9', 'X1V', 'M9Y', 'HFK', 'K85', 'NCJ', 'XBR', 'VR5', 'V ...

# %%
final = [['COM', 0]]
count = 1

current = ['COM']
while len(total_1) != len(final):
    next_list_total = []
    for orbit in current:
        for i in total:
            if i[0] == orbit:
                next_list_total.append(i[1])
                final.append([orbit, count])
    count += 1
    current = next_list_total

solution = []
for megoldas in final:
    solution.append(megoldas[1])
    sum(solution)
print(sum(solution))
# Out:
# 387356

# %%
#YOU

final = [['COM', 0]]
count = 1
youlist = []

current = ['YOU']
for i in range(len(content)):
    new_list = []
    for i in total:
        if i[1] in current:
            print('i', i[1])
            new_list.append(i[0])
            youlist.append(i[0])
            count += 1
            current = new_list
# Out:
# i YOU
# i X1T
# i Q7S
# i WLT
# i PZ1
# i M5X
# i JGG
# i JVW
# i 37X
# i DZT
# i XBR
# i BFJ
# i 158
# i 4NP
# i 1MR
# i 81D
# i 6QN
# i 81D
# i 6QN
# i YVB
# i DKL
# i 1N1
# i B6K
# i ZLW
# i FDV
# i 62W
# i FDV
# i 62W
# i DG4
# i PY3
# i LQQ
# i JDN
# i XDZ
# i PVX
# i R26
# i 8T8
# i NVK
# i MZY
# i 956
# i R2L
# i V3L
# i K8B
# i H58
# i 5T8
# i 266
# i 6FY
# i HH1
# i STL
# i BLQ
# i SM3
# i XQD
# i SM3
# i XQD
# i K6F
# i YQP
# i FMW
# i Z83
# i Q7N
# i 9TH
# i MBX
# i SKC
# i QFH
# i NB5
# i GNG
# i 1R1
# i CPG
# i L71
# i 9JW
# i 3NY
# i JZR
# i 34T
# i ZBR
# i L7K
# i 6MB
# i G2X
# i CJY
# i 828
# i KM4
# i YZY
# i WJH
# i MGC
# i X6F
# i 5PM
# i RSR
# i BG5
# i VXN
# i YSZ
# i 724
# i FRF
# i DR4
# i WNW
# i FGB
# i MXR
# i 1C6
# i FGB
# i MXR
# i FGB
# i MXR
# i VJ1
# i GKV
# i RQW
# i 883
# i 7YL
# i WMJ
# i 4WH
# i LLY
# i 48Z
# i T91
# i 48Z
# i T91
# i 7NX
# i K3L
# i YVK
# i MJW
# i FQF
# i R8F
# i ZWF
# i F87
# i JYR
# i K54
# i 2BP
# i 33X
# i GZS
# i 33X
# i GZS
# i 763
# i 7LB
# i KWM
# i R45
# i ZN4
# i RXM
# i 58V
# i JKC
# i 58V
# i JKC
# i 2YP
# i WWP
# i MZL
# i WWP
# i MZL
# i 49T
# i J6D
# i 7FQ

# %%
#youlist

# %%
#SAN

final = [['COM', 0]]
count = 1
sanlist = []

current = ['SAN']
for i in range(len(content)):
    new_list = []
    for i in total:
        if i[1] in current:
            print('i', i[1])
            new_list.append(i[0])
            sanlist.append(i[0])
            count += 1
            current = new_list
# Out:
# i SAN
# i 186
# i XWH
# i P53
# i 15N
# i 5Y1
# i BD6
# i 9QP
# i RQ5
# i ZJH
# i CC1
# i TH7
# i RV7
# i 2R5
# i 2K8
# i KL2
# i V2Q
# i QPV
# i K85
# i 23D
# i N3Y
# i 6YZ
# i QD4
# i JS3
# i XWC
# i N1X
# i TQR
# i WPJ
# i WYT
# i 7R8
# i 5PJ
# i NN1
# i YVH
# i 5DS
# i P13
# i BHY
# i BM6
# i V22
# i R51
# i BS9
# i TWM
# i 8FK
# i H4Z
# i NBP
# i W8V
# i 9Y9
# i 9ST
# i 94F
# i TSZ
# i PTJ
# i DG9
# i SM1
# i MND
# i D8R
# i 1PC
# i GC8
# i VC2
# i WK3
# i RMB
# i F5W
# i 88L
# i W7M
# i VSS
# i VJ6
# i DMD
# i CNG
# i HZV
# i MNW
# i GGY
# i 9XR
# i 1ZK
# i XHF
# i J9X
# i B87
# i 9RT
# i 3XB
# i PHM
# i J5G
# i PHM
# i J5G
# i D5X
# i 6XP
# i K1R
# i 4DM
# i HKN
# i BNJ
# i F7M
# i 68Z
# i P9P
# i NQZ
# i KHT
# i LGX
# i HK5
# i 954
# i WHN
# i 9C5
# i D66
# i ZGW
# i BXB
# i RD8
# i GZL
# i 62C
# i 7HY
# i C2J
# i GZL
# i 62C
# i 7HY
# i C2J
# i 62C
# i 7HY
# i C2J
# i 7HY
# i C2J
# i 2R7
# i SZZ
# i KYD
# i HHX
# i Q43
# i 614
# i ZDV
# i PJ9
# i VLW
# i VR5
# i 554
# i GGJ
# i JZ3
# i CYT
# i 3SS
# i GDH
# i CYT
# i 3SS
# i GDH
# i SPF
# i GF2
# i 3JQ
# i BL1
# i ZHW
# i H3H
# i CD9
# i JZT
# i CD9
# i JZT
# i VV7
# i 447
# i G1L
# i 5CV
# i 55S
# i 9G4
# i VBT
# i H1D
# i T69
# i RCT
# i LL2
# i RFX
# i 9CY
# i RFX
# i 9CY
# i XV7
# i 5BT
# i QRK
# i JYK
# i 9S4
# i CXQ
# i JYK
# i 9S4
# i CXQ
# i LVR
# i LGK
# i DKJ
# i 9ZH
# i H93
# i 519
# i SBN
# i M45
# i KXF
# i XGM
# i JWF
# i WZD
# i XGM
# i JWF
# i WZD
# i JWF
# i WZD
# i 97C
# i CTD
# i 1NT
# i Q55
# i HJT
# i GD4
# i B5F
# i 73G
# i VL3
# i VJQ
# i XT9
# i ZCY
# i VJQ
# i XT9
# i ZCY
# i LGV
# i VVT
# i WZ9
# i 15S
# i PXC
# i JG8
# i 3VB
# i CGC
# i 7QG
# i 929
# i VPT
# i BLD
# i DS4
# i DZS
# i DS4
# i DZS
# i YS8
# i QKL
# i 3WB
# i GZ4
# i X69
# i LPL
# i 6YP
# i BCB
# i FZ7
# i X8R
# i GF7
# i DGS
# i PYL
# i DGS
# i PYL
# i 41F
# i BPG
# i B1R
# i 7J9
# i RR9
# i R5B
# i HR8
# i LTW
# i L2T
# i KSX
# i QJG
# i F65
# i YQ9
# i 717
# i TQ2
# i FQ6
# i CLH
# i 6CT
# i T71
# i TJM
# i 45L
# i LRJ
# i GH2
# i J71
# i 1SR
# i JRS
# i ZP8
# i 3FF
# i SCB
# i RC1
# i RW9
# i 325
# i HP6
# i Z93
# i H55
# i Z4K
# i D7G
# i K65
# i BKX
# i CHC
# i HP7
# i SP2
# i FJN
# i F71
# i MPM
# i Y2Q
# i ZZM
# i L8Y
# i 1DN
# i 8DX
# i TZJ
# i 8K5
# i F1B
# i MB3
# i QB4
# i 7KF
# i QK9
# i JSX
# i V4N
# i CYB
# i 38H
# i V4N
# i CYB
# i 38H
# i CYB
# i 38H
# i FRW
# i QKW
# i JX6
# i JKN
# i GZ9
# i Z4B
# i 6XV
# i RT1
# i BT8
# i PQC
# i S55
# i 89D
# i 2D3
# i H33
# i DGR
# i QCQ
# i JLK
# i 441
# i QCQ
# i JLK
# i 441
# i ZTW
# i 84W
# i RXS
# i V1D
# i FVD
# i 365
# i SZ6
# i 1C6
# i FGB
# i MXR
# i 1C6
# i FGB
# i MXR
# i FGB
# i MXR
# i VJ1
# i GKV
# i RQW
# i 883
# i 7YL
# i WMJ
# i 4WH
# i LLY
# i 48Z
# i T91
# i 48Z
# i T91
# i 7NX
# i K3L
# i YVK
# i MJW
# i FQF
# i R8F
# i ZWF
# i F87
# i JYR
# i K54
# i 2BP
# i 33X
# i GZS
# i 33X
# i GZS
# i 763
# i 7LB
# i KWM
# i R45
# i ZN4
# i RXM
# i 58V
# i JKC
# i 58V
# i JKC
# i 2YP
# i WWP
# i MZL
# i WWP
# i MZL
# i 49T
# i J6D
# i 7FQ

# %%
#sanlist

# %%
yousanlist = []

for objects in youlist:
    if objects not in sanlist:
        yousanlist.append(objects)
        
for objectss in sanlist:
    if objectss not in youlist:
        yousanlist.append(objectss)

print(len(set(yousanlist)))
# Out:
# 532
