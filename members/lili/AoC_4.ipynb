# %% [markdown]
# You arrive at the Venus fuel depot only to discover it's protected by a password. The Elves had written the password on a sticky note, but someone threw it out.
#
# However, they do remember a few key facts about the password:
#
# It is a six-digit number.
#
# The value is within the range given in your puzzle input.
#
# Two adjacent digits are the same (like 22 in 122345).
#
# Going from left to right, the digits never decrease; they only ever increase or stay the same (like 111123 or 135679).
#
# Other than the range rule, the following are true:
#
# 111111 meets these criteria (double 11, never decreases).
#
# 223450 does not meet these criteria (decreasing pair of digits 50).
#
# 123789 does not meet these criteria (no double).
#
# How many different passwords within the range given in your puzzle input meet these criteria?

# %%
input_range = 739105-246515
input_range
# Out:
# 492590

# %%
potential = []
for i in range(246515,739105):
    potential.append(str(i)) 
    
ok = []
for i in range(0,len(potential)):
    if potential[i][0] == potential[i][1] or potential[i][1] == potential[i][2]\
    or potential[i][2] == potential[i][3] or potential[i][3] == potential[i][4]\
    or potential[i][4] == potential[i][5]:
        if potential[i][0] <= potential[i][1] and potential[i][1] <= potential[i][2]\
        and potential[i][2] <= potential[i][3] and potential[i][3] <= potential[i][4]\
        and potential[i][4] <= potential[i][5]:
            ok.append(potential[i])
len(ok)
# Out:
# 1048

# %%
potential = ['111111','223450','123789']
    
ok = []
for i in range(0,len(potential)):
    if potential[i][0] == potential[i][1] or potential[i][1] == potential[i][2]\
    or potential[i][2] == potential[i][3] or potential[i][3] == potential[i][4]\
    or potential[i][4] == potential[i][5]:
        if potential[i][0] <= potential[i][1] and potential[i][1] <= potential[i][2]\
        and potential[i][2] <= potential[i][3] and potential[i][3] <= potential[i][4]\
        and potential[i][4] <= potential[i][5]:
            ok.append(potential[i])
            
len(ok)
# Out:
# 1

# %% [markdown]
# --- Part Two ---
#
# An Elf just remembered one more important detail: the two adjacent matching digits are not part of a larger group of matching digits.
#
# Given this additional criterion, but still ignoring the range rule, the following are now true:
#
# 112233 meets these criteria because the digits never decrease and all repeated digits are exactly two digits long.
#
# 123444 no longer meets the criteria (the repeated 44 is part of a larger group of 444).
#
# 111122 meets the criteria (even though 1 is repeated more than twice, it still contains a double 22).
#
# How many different passwords within the range given in your puzzle input meet all of the criteria?

# %%
print(ok)
# Out:
# ['246666', '246667', '246668', '246669', '246677', '246678', '246679', '246688', '246689', '246699', '246777', '246778', '246779', '246788', '246799', '246888', '246889', '246899', '246999', '247777', '247778', '247779', '247788', '247789', '247799', '247888', '247889', '247899', '247999', '248888', '248889', '248899', '248999', '249999', '255555', '255556', '255557', '255558', '255559', '255566', '255567', '255568', '255569', '255577', '255578', '255579', '255588', '255589', '255599', '255666', '255667', '255668', '255669', '255677', '255678', '255679', '255688', '255689', '255699', '255777', '255778', '255779', '255788', '255789', '255799', '255888', '255889', '255899', '255999', '256666', '256667', '256668', '256669', '256677', '256678', '256679', '256688', '256689', '256699', '256777', '256778', '256779', '256788', '256799', '256888', '256889', '256899', '256999', '257777', '257778', '257779', '257788', '257789', '257799', '257888', '257889', '257899', '257999', '258888', '258889
# ...

# %%
really_ok = []
for i in range(0,len(ok)):
    if ok[i][0] == ok[i][1] and ok[i][1] != ok[i][2]\
    or ok[i][1] == ok[i][2] and ok[i][2] != ok[i][3] and ok[i][0] != ok[i][1]\
    or ok[i][2] == ok[i][3] and ok[i][3] != ok[i][4] and ok[i][1] != ok[i][2]\
    or ok[i][3] == ok[i][4] and ok[i][4] != ok[i][5] and ok[i][2] != ok[i][4]\
    or ok[i][4] == ok[i][5] and ok[i][3] != ok[i][4]:
        really_ok.append(ok[i])

len(really_ok)
# Out:
# 677
