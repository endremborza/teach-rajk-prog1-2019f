# %% [markdown]
# # Turing-gép és strukturális programozás

# %% [markdown]
# ### Table of Contents
# - [Slide 1: Turing-gép informálisan](#slide-prog1:turinginf)
#   - [Turing-gép informálisan](#content-prog1:turinginfdef)
# - [Slide 2: Turing-gép formálisan](#slide-prog1:turingformal)
#   - [Turing-gép formálisan](#content-prog1:turingformaldef)
# - [Slide 3:](#slide-prog1:turingexbb-slide-prog1:turingexbbcards-slide-prog1:turingexbbaut-slide-prog:busyb3cards-slide-prog:busy_beaver_counts)
#   - [Slide 3/1: Turing-gép példa](#slide-prog1:turingexbb)
#     - [2 állású (egyik) legjobb Busy Beaver](#content-prog1:busyb2tex)
#   - [Slide 3/2: Turing-gép kártyák](#slide-prog1:turingexbbcards)
#     - [Busy beaver kártyák](#content-prog1:busyb2cards)
#   - [Slide 3/3: Turing-gép automata](#slide-prog1:turingexbbaut)
#     - [Busy beaver automata](#content-prog1:busyb2aut)
#   - [Slide 3/4: 3 kártyás Busy Beaver](#slide-prog:busyb3cards)
#     - [3 kártyás Busy Beaver](#content-prog1:busyb3cards)
#   - [Slide 3/5: Busy Beaver számok](#slide-prog:busy_beaver_counts)
#     - [Busy Beaver számok](#content-prog:busy_beaver_counts)
# - [Slide 4: OOP állapot vs Turing-gép állás](#slide-prog1:oopvsturing)
#   - [Állapot (state)](#content-prog1:statedef)
#   - [Turing-gép állás (kártya)](#content-prog1:turingstate)
# - [Slide 5: Kihívások](#slide-prog1:turingchall)
#   - [Turing kihívások](#content-prog1:turingchall)
# - [Slide 6: Hogyan nézek a gépre - paradigma](#slide-prog1:turingparadigm)
#   - [A mi paradigmánk](#content-prog1:ourparadigm)
# - [Slide 7: Strukturált programozás](#slide-prog1:structexs)
#   - [Struktúrák példákkal](#content-prog1:progstructuresex)
#   - [Struktúrák tulajdonságok](#content-prog1:structeatts)
# - [Slide 8: Turing teljesség](#slide-prog1:turingcomplete)
#   - [Turing teljesség](#content-prog1:turingcompletedef)
#   - [Mi kell Turing teljességhez?](#content-prog1:turingcompleteneed)

# %% [markdown]
# <h2><span id="slide-prog1:turinginf">Slide 1: Turing-gép informálisan</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:turinginfdef">Turing-gép informálisan</span></h3>

# %% [markdown]
# - tetszőleges hosszúságú, cellákra osztott szalag, rajta jelekkel (cellánként egy jel)
# - gép ami olvassa és írja
#   - beépített, egyértelmű instrukciók
#   - meghatározott helyen kezd a szalagon
#   - elolvas egy jelet és az instrukciók függvényében:
#     - ír a helyére valamit, majd elmozdul jobbra/balra és beolvassa ami ott van
#     - leáll (HALT)

# %% [markdown]
# <h2><span id="slide-prog1:turingformal">Slide 2: Turing-gép formálisan</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:turingformaldef">Turing-gép formálisan</span></h3>

# %% [markdown]
# $ M = \langle Q, \Gamma, \delta, q_0, q_f \rangle $
#
# - $Q$ - állások listája
#   - ezen belül $q_0$ a kezdőállást, $q_f$ pedig a lehetséges végső "halting" állások
# - $\Gamma$ - szalagon szerepelhető jelek ábécéje
# - $\delta$ az utasításkészlet egy függvényben: $(Q \setminus q_f) \times \Gamma \rightarrow Q \times \Gamma \times \{L,R\}$

# %% [markdown]
# <h2><span id="slide-prog1:turingexbb-slide-prog1:turingexbbcards-slide-prog1:turingexbbaut-slide-prog:busyb3cards-slide-prog:busy_beaver_counts">Slide 3:</span></h2>

# %% [markdown]
# <h3><span id="slide-prog1:turingexbb">Slide 3/1: Turing-gép példa</span></h3>

# %% [markdown]
# <h4><span id="content-prog1:busyb2tex">2 állású (egyik) legjobb Busy Beaver</span></h4>

# %% [markdown]
# $ \Gamma = \langle 1,0 \rangle , Q=\langle A,B,HALT \rangle $
#
# $ q_0 = A, q_f = HALT $
#
# $\delta$ következő formákban felírva:
#
# - kártyák
# - automata

# %% [markdown]
# <h3><span id="slide-prog1:turingexbbcards">Slide 3/2: Turing-gép kártyák</span></h3>

# %% [markdown]
# <h4><span id="content-prog1:busyb2cards">Busy beaver kártyák</span></h4>

# %% [markdown]
# - A
#
# | input | write | step  | next state |
# |-------|-------|-------|------------|
# | 1     | 1     | left  | B          |
# | 0     | 1     | right | B          |
#
# ---
#
# - B
#
# | input | write | step  | next state |
# |-------|-------|-------|------------|
# | 1     | 1     | right  | HALT          |
# | 0     | 1     | left | A          |

# %% [markdown]
# <h3><span id="slide-prog1:turingexbbaut">Slide 3/3: Turing-gép automata</span></h3>

# %% [markdown]
# <h4><span id="content-prog1:busyb2aut">Busy beaver automata</span></h4>

# %% [markdown]
# [automata](http://www.multiwingspan.co.uk/images/comp/a23/turing3.png)

# %% [markdown]
# <h3><span id="slide-prog:busyb3cards">Slide 3/4: 3 kártyás Busy Beaver</span></h3>

# %% [markdown]
# <h4><span id="content-prog1:busyb3cards">3 kártyás Busy Beaver</span></h4>

# %% [markdown]
# | input | A | B | C
# |-------|-------|-------|------------|
# | 0 | 1RB | 0RC | 1LC
# | 1 |1RH | 1RB | 1LA

# %% [markdown]
# <h3><span id="slide-prog:busy_beaver_counts">Slide 3/5: Busy Beaver számok</span></h3>

# %% [markdown]
# <h4><span id="content-prog:busy_beaver_counts">Busy Beaver számok</span></h4>

# %% [markdown]
# - 2 kártyás
#   - 6
# - 3 kártyás
#   - 21 <!-- .element: class="fragment"  -->
# - 4 kártyás
#   - 107 <!-- .element: class="fragment"  -->
# - 5 kártyás
#   - 47176870 ? <!-- .element: class="fragment"  -->
# - 6 kártyás
#   - $7.4 \times 10^{36534}$ ? <!-- .element: class="fragment"  -->

# %% [markdown]
# <h2><span id="slide-prog1:oopvsturing">Slide 4: OOP állapot vs Turing-gép állás</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:statedef">Állapot (state)</span></h3>

# %% [markdown]
# Minden a program által adott pontban elérhető és általa tárolt információ

# %% [markdown]
# <h3><span id="content-prog1:turingstate">Turing-gép állás (kártya)</span></h3>

# %% [markdown]
# - beolvasott jel alapján:
#   - mit írjon
#   - melyik legyen a következő jel amit beolvas
#   - milyen következő állásba menjen
# - meghatározott számú van (köztük HALT)

# %% [markdown]
# <h2><span id="slide-prog1:turingchall">Slide 5: Kihívások</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:turingchall">Turing kihívások</span></h3>

# %% [markdown]
# - Ember létre tudjon hozni ilyet
# - Készíteni olyan univerzális gépet, ami megért egy ilyen leírást, és onnantól így működik (UTM)
# - Egyre komplexebb, érdekesebb dolgokat, egyre érthetőbben leírni
# - Megtalálni a korlátokat

# %% [markdown]
# <h2><span id="slide-prog1:turingparadigm">Slide 6: Hogyan nézek a gépre - paradigma</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:ourparadigm">A mi paradigmánk</span></h3>

# %% [markdown]
# - ***imperatív***: utasításonként változtatom a program állapotát, amíg el nem érek a kívánt állapotba
#   - ***procedurális***: meghívható utasítássorozatok, procedúrák (függvények)
#   - ***struktúrált***: blokkok, elágazások, for/while struktúrák (iterációk)
#   - ***objektumorientált***: függvényeket, adatot, speciális típusokat egységesen objektumként tároljuk az állapotban
# - ***generikus***: típusok tekintetében általánosítható függvények

# %% [markdown]
# <h2><span id="slide-prog1:structexs">Slide 7: Strukturált programozás</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:progstructuresex">Struktúrák példákkal</span></h3>

# %% [markdown]
# - elágazás
#   - if
#   - else-if
#   - switch/case
# - iteráció
#   - while
#   - for
#   - do-while/until
# - blokk
#   - függvény
#   - procedúra

# %% [markdown]
# <h3><span id="content-prog1:structeatts">Struktúrák tulajdonságok</span></h3>

# %% [markdown]
# - elágazás
#   - feltétel
#   - ág
# - iteráció
#   - feltétel
#   - ciklusmag
# - blokk
#   - utasítássorozat

# %% [markdown]
# <h2><span id="slide-prog1:turingcomplete">Slide 8: Turing teljesség</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:turingcompletedef">Turing teljesség</span></h3>

# %% [markdown]
# Egy olyan eszköz Turing teljes, ami képes szimulálni bármely specifikus Turing gépet

# %% [markdown]
# <h3><span id="content-prog1:turingcompleteneed">Mi kell Turing teljességhez?</span></h3>

# %% [markdown]
# A mi paradigmánkban, ha egy programnyelvben van:
#
# - értékadás
# - iteráció
#
# akkor Turing teljes
