# %% [markdown]
# # Input, Output, Számítógépes alapok

# %% [markdown]
# ### Table of Contents
# - [Slide 1: Input](#slide-prog1:input)
#   - [Input fogalmak](#content-prog1:inputphrases)
#   - [Input](#content-prog1:inputdef)
# - [Slide 2: Output](#slide-prog1:output)
#   - [Output fogalmak](#content-prog1:outputphrases)
#   - [Output](#content-prog1:outputdef)
# - [Slide 3: Paraméter - Visszatérési érték](#slide-prog1:paramreturn)
#   - [Paraméter - Input](#content-prog1:parinput)
#   - [Visszatérési érték - Output](#content-prog1:returnout)
# - [Slide 4: cmd demo](#slide-prog1:commandline_demo)
#   - [Command line demo](#content-prog1:commandline_demo)
# - [Slide 5: Git demo](#slide-prog1:git_demo)
#   - [Git demo](#content-prog1:git_demo)

# %% [markdown]
# <h2><span id="slide-prog1:input">Slide 1: Input</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:inputphrases">Input fogalmak</span></h3>

# %% [markdown]
# - *input*
# - *meg van adva*
# - *xy alapján a program kiszámolja*
# - *beírjuk*
# - *bemenet*

# %% [markdown]
# <h3><span id="content-prog1:inputdef">Input</span></h3>

# %% [markdown]
# Az az objektum, ami kívülről bekerül a program állapotába

# %% [markdown]
# <h2><span id="slide-prog1:output">Slide 2: Output</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:outputphrases">Output fogalmak</span></h3>

# %% [markdown]
# - *output*
# - *megadja*
# - *kiszámolja*
# - *kidobja*
# - *kimenet*
# - *megkapom*

# %% [markdown]
# <h3><span id="content-prog1:outputdef">Output</span></h3>

# %% [markdown]
# Az az objektum, ami kikerül a program állapotából és valahol máshol felhasználásra kerül

# %% [markdown]
# <h2><span id="slide-prog1:paramreturn">Slide 3: Paraméter - Visszatérési érték</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:parinput">Paraméter - Input</span></h3>

# %% [markdown]
# A függvény meghívásakor megadott paraméter bekerül a függvény lokális keretébe, ami ha a függvényre tekintünk a programként, értelmezhető inputként. <!-- .element: class="fragment" data-fragment-index="1" -->

# %% [markdown]
# <h3><span id="content-prog1:returnout">Visszatérési érték - Output</span></h3>

# %% [markdown]
# A visszatérési érték a return utasítás végrehajtásával kikerül a lokális keretből (az összes többi változóval együtt) és átkerül abba a keretbe ami meghívta a függvényt, ami várhatóan fel fogja használni. Így a függvény szempontjából output. <!-- .element: class="fragment" data-fragment-index="1" -->

# %% [markdown]
# <h2><span id="slide-prog1:commandline_demo">Slide 4: cmd demo</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:commandline_demo">Command line demo</span></h3>

# %% [markdown]
# - Command line (parancssor)
#   - DOS batch language
#     - batch file
#   - bash
#     - shell script
#   - PowerShell
# - PATH változó
# - Parancsikonok

# %% [markdown]
# <h2><span id="slide-prog1:git_demo">Slide 5: Git demo</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:git_demo">Git demo</span></h3>

# %% [markdown]
# - init
# - add
# - commit
# - push/pull
# - branch
