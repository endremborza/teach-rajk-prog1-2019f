# %% [markdown]
# # Tudás és Számítógép

# %% [markdown]
# ### Table of Contents
# - [Slide 1: Kurzus menete](#slide-prog1:agenda)
#   - [Kurzus menete](#content-prog1:agenda)
# - [Slide 2: Összeszedett kompetenciák](#slide-prog1:coursecomps)
#   - [Kurzus menete](#content-prog1:agenda)
#   - [Mit kellene tudni?](#content-prog1:whattoknow)
# - [Slide 3: Tudás típusai](#slide-prog1:knowledgetypes)
#   - [Deklaratív tudás](#content-prog1:declarativek)
#   - [Imperatív tudás](#content-prog1:imperativek)
#   - [Deklaratív példák](#content-prog1:declarativeex)
#   - [Imperatív példák](#content-prog1:imperativeex)
# - [Slide 4:](#slide-prog1:knowtopcex-slide-prog1:knowtopcsqrt-slide-prog1:knowtopcsqrt2)
#   - [Slide 4/1: Mit adunk át a gépnek?](#slide-prog1:knowtopcex)
#     - [Mit adunk át a gépnek?](#content-prog1:knowtopcex)
#   - [Slide 4/2: Példa tudásátadásra](#slide-prog1:knowtopcsqrt)
#     - [Tudás Gyökvonásról](#content-prog1:sqrt-knowledge-ex)
#   - [Slide 4/3: Gyökös példa 2](#slide-prog1:knowtopcsqrt2)
#     - [Ember](#content-prog1:sqrtex_human)
#     - [Gép](#content-prog1:sqrtex_machine)
# - [Slide 5: Specifikáció](#slide-prog1:specdef)
#   - [Specifikáció](#content-prog1:specdef)
# - [Slide 6:](#slide-prog1:specex1-slide-prog1:specex2)
#   - [Slide 6/1: Példa](#slide-prog1:specex1)
#     - [Specifikáció példa](#content-prog1:specex1)
#   - [Slide 6/2: Specifikáció példa 2](#slide-prog1:specex2)
#     - [Specifikáció példa 2](#content-prog1:specex2)
# - [Slide 7:](#slide-prog1:speccomplete-slide-prog1:specdetail)
#   - [Slide 7/1: Teljesség](#slide-prog1:speccomplete)
#     - [Specifikáció teljessége](#content-prog1:speccomplete)
#   - [Slide 7/2: Részletesség](#slide-prog1:specdetail)
#     - [Specifikáció részletessége](#content-prog1:specdetail)
# - [Slide 8: Számítógép alkotóelemei](#slide-prog1:parts_of_computer)
#   - [Számítógép alkotóelemei](#content-prog1:parts_of_computer)
# - [Additional content](#additionallecturecontent-4)
#   - [Specifikáció párosítás jelölés help](#content-prog1:specpairhelp)

# %% [markdown]
# <h2><span id="slide-prog1:agenda">Slide 1: Kurzus menete</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:agenda">Kurzus menete</span></h3>

# %% [markdown]
# 1. Tudás és számítógép
# 2. Alapfogalmak
#     - adat, kifejezés, utasítás, állapot <!-- level=2 -->
#     - globális/lokális keret, függvény <!-- level=2 -->
#     - input, output <!-- level=2 -->
# 3. Számításelmélet alapok
#     - Turing-gép, halting problem <!-- level=2 -->
# 4. Struktúrált programozás
#     - blokk, elágazás, iteráció <!-- level=2 -->
# 5. Algoritmustervezés
#     - részproblémákra bontás <!-- level=2 -->
#     - gyakorlás <!-- level=2 -->
# 6. Interakció programokkal
#     - hibakeresés, tesztelés <!-- level=2 -->
# 7. Programnyelvek
#     - low level vs high level <!-- level=2 -->
#     - statically vs dinamicaly typed <!-- level=2 -->
# 8. Python use-casek
#     - adatelemzés, scraping, web applikációk, task automatizáció <!-- level=2 -->
# 9. Extra (megbeszéljük mi szimpi)
#     - adatbázisok, kriptográfia, bonyolultságanalízis, AI, machine learning, blockchain, quantum computing... <!-- level=2 -->

# %% [markdown]
# <h2><span id="slide-prog1:coursecomps">Slide 2: Összeszedett kompetenciák</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:agenda">Kurzus menete</span></h3>

# %% [markdown]
# 1. Tudás és számítógép
# 2. Alapfogalmak
#     - adat, kifejezés, utasítás, állapot <!-- level=2 -->
#     - globális/lokális keret, függvény <!-- level=2 -->
#     - input, output <!-- level=2 -->
# 3. Számításelmélet alapok
#     - Turing-gép, halting problem <!-- level=2 -->
# 4. Struktúrált programozás
#     - blokk, elágazás, iteráció <!-- level=2 -->
# 5. Algoritmustervezés
#     - részproblémákra bontás <!-- level=2 -->
#     - gyakorlás <!-- level=2 -->
# 6. Interakció programokkal
#     - hibakeresés, tesztelés <!-- level=2 -->
# 7. Programnyelvek
#     - low level vs high level <!-- level=2 -->
#     - statically vs dinamicaly typed <!-- level=2 -->
# 8. Python use-casek
#     - adatelemzés, scraping, web applikációk, task automatizáció <!-- level=2 -->
# 9. Extra (megbeszéljük mi szimpi)
#     - adatbázisok, kriptográfia, bonyolultságanalízis, AI, machine learning, blockchain, quantum computing... <!-- level=2 -->

# %% [markdown]
# <h3><span id="content-prog1:whattoknow">Mit kellene tudni?</span></h3>

# %% [markdown]
# 1. Megfogalmazni egy programozási problémát <!-- .element: class="fragment"  -->
# 1. Számításelmélet értelmét elmagyarázni <!-- .element: class="fragment"  -->
# 1. Lebontani egy komplex problémát egyszerűbbekre <!-- .element: class="fragment"  -->
# 1. Megérteni egy leírt programot <!-- .element: class="fragment"  -->
# 1. Megírni egy programot <!-- .element: class="fragment"  -->
# 1. Találni érdeklődést és folytatást <!-- .element: class="fragment"  -->

# %% [markdown]
# <h2><span id="slide-prog1:knowledgetypes">Slide 3: Tudás típusai</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:declarativek">Deklaratív tudás</span></h3>

# %% [markdown]
# A "mit?" kérdésre adott válasz egy probléma kapcsán

# %% [markdown]
# <h3><span id="content-prog1:imperativek">Imperatív tudás</span></h3>

# %% [markdown]
# A "hogyan" kérdésre adott válasz egy probléma kapcsán

# %% [markdown]
# <h3><span id="content-prog1:declarativeex">Deklaratív példák</span></h3>

# %% [markdown]
# - tervrajz
# - térképjelzés
# - anatómiai ábra
# - ...

# %% [markdown]
# <h3><span id="content-prog1:imperativeex">Imperatív példák</span></h3>

# %% [markdown]
# - recept
# - IKEA útmutató
# - útvonalterv
# - ...

# %% [markdown]
# <h2><span id="slide-prog1:knowtopcex-slide-prog1:knowtopcsqrt-slide-prog1:knowtopcsqrt2">Slide 4:</span></h2>

# %% [markdown]
# <h3><span id="slide-prog1:knowtopcex">Slide 4/1: Mit adunk át a gépnek?</span></h3>

# %% [markdown]
# <h4><span id="content-prog1:knowtopcex">Mit adunk át a gépnek?</span></h4>

# %% [markdown]
# Egy probléma megoldására szeretnénk megtanítani/megkérni:
#
# tetszőleges $x$-re, számolja ki $ \sqrt{x} $-et úgy, hogy csak osztani, szorozni, meg összeadni tud

# %% [markdown]
# <h3><span id="slide-prog1:knowtopcsqrt">Slide 4/2: Példa tudásátadásra</span></h3>

# %% [markdown]
# <h4><span id="content-prog1:sqrt-knowledge-ex">Tudás Gyökvonásról</span></h4>

# %% [markdown]
# - deklaratív tudás:
#   - $ \sqrt{x} = y \Leftrightarrow y^2=x $
#   - $ x < y^2 \Leftrightarrow \sqrt{x} < y $
#   - $ ( (y_1 < x \land y_2 < x) \lor (y_1 > x \land y_2 > x) ) \Rightarrow $
#   - $ \Rightarrow ( |x  - y_1| < |x - y_2| \Leftrightarrow |x^2  - y_1^2| < |x^2 - y_2^2| ) $
#   - ...
# - imperatív tudás:
#   - tippelünk egy kezdeti $ G $ -t, és ameddig nem elég jó, $ G' = \frac{G+\frac{x}{G}}{2} $ -vel közelítünk, így tetszőlegesen közel kerülünk az eredményhez
#
#
# (minden nemnegatív számok esetén)

# %% [markdown]
# <h3><span id="slide-prog1:knowtopcsqrt2">Slide 4/3: Gyökös példa 2</span></h3>

# %% [markdown]
# <h4><span id="content-prog1:sqrtex_human">Ember</span></h4>

# %% [markdown]
# okos, kreatív, tud következtetni, memóriája ködös,
#  szeretné minél kevesebbet nyomkodni a számológépet
#
# - felhasznál csomó meglévő deklaratív tudást
# - összeállítja egy komplex tippelési folyamattá
# - tippek eredményéből továbbfejleszti a folyamatot
# - felhasznál olyan komplex fogalmakat mint nagyságrend, vagy előjelváltás

# %% [markdown]
# <h4><span id="content-prog1:sqrtex_machine">Gép</span></h4>

# %% [markdown]
# buta, nincs önálló gondolata, memóriája tökéletes
# másodpercenként töbmilliárd műveletet el tud végezni,
#
# - tippel egy nagyon rosszat, pl G = 1
# - valaki megtanította neki hogy $G' = \frac{G+\frac{x}{G}}{2}$ közelít, szóval elkezdi
# - Megoldandó probléma: $ \sqrt{1366561} = ? $
# - 1, 683281, 341641, 170822, 85415, 42715, 21373, 10718, 5423, 2837, 1659, 1241, 1171, 1169

# %% [markdown]
# <h2><span id="slide-prog1:specdef">Slide 5: Specifikáció</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:specdef">Specifikáció</span></h3>

# %% [markdown]
# Egyfajta deklaratív leírása egy programnak
#
# Miből, mit?
#
# - állapottér - bemenő/kimenő adatok
# - előfeltétel - amit tudunk a bemenetről
# - utófeltétel - az eredmény kiszámítási szabálya (amit tudunk az eredményről)
#
# legyen **teljes** és **részletes**

# %% [markdown]
# <h2><span id="slide-prog1:specex1-slide-prog1:specex2">Slide 6:</span></h2>

# %% [markdown]
# <h3><span id="slide-prog1:specex1">Slide 6/1: Példa</span></h3>

# %% [markdown]
# <h4><span id="content-prog1:specex1">Specifikáció példa</span></h4>

# %% [markdown]
# Valós számok halmazán megoldható másodfokú egyneletet oldjon meg a program, ami $ax^2+bx+c=0$ formában van megadva
#
# - Á: $(a,b,c,x_1,x_2 \in \mathbb{R})$ <!-- .element: class="fragment" data-fragment-index="1" -->
# - Ef: $(a \neq 0 \land b^2-4ac \geq 0)$ <!-- .element: class="fragment" data-fragment-index="2" -->
# - Uf: $ (x_1 = \frac{-b + \sqrt{b^2-4ac}}{2a} \land x_2 = \frac{-b - \sqrt{b^2-4ac}}{2a})$ <!-- .element: class="fragment" data-fragment-index="3" -->

# %% [markdown]
# <h3><span id="slide-prog1:specex2">Slide 6/2: Specifikáció példa 2</span></h3>

# %% [markdown]
# <h4><span id="content-prog1:specex2">Specifikáció példa 2</span></h4>

# %% [markdown]
# Valós számok halmazán megoldható másodfokú egyneletet oldjon meg a program, ami $ax^2+bx+c=0$ formában van megadva
#
# - Á: $(a,b,c,x_1,x_2 \in \mathbb{R})$
# - Ef: $(a \neq 0 \land b^2-4ac \geq 0)$
# - Uf: $ (\forall i (ax_i^2+bx_i+c=0) \land ( x_1 = x_2 \iff b^2-4ac = 0 ))$

# %% [markdown]
# <h2><span id="slide-prog1:speccomplete-slide-prog1:specdetail">Slide 7:</span></h2>

# %% [markdown]
# <h3><span id="slide-prog1:speccomplete">Slide 7/1: Teljesség</span></h3>

# %% [markdown]
# <h4><span id="content-prog1:speccomplete">Specifikáció teljessége</span></h4>

# %% [markdown]
# Amit az előfeltétel megenged az állapottéren belül, azt az utófeltételnek kezelnie kell
#
# Pl:
#
# - Válassza ki két szám közül azt amelyiknek több prím osztója van
#   - több különböző vagy több összesen?
#   - mi van ha ugyanannyi?
# - Válassza ki egy számsorból azt az 5 számot ami legjobban eltér az átlagtól
#   - mi van ha nincs 5 szám a számsorban?
#   - mi van ha minden szám ugyanaz?
# - Sakktáblán szereplő állásról döntse el hogy matt-e.
#   - mi van ha mindkét fél sakkban van?
#   - lehet 11 királynő valakinél?

# %% [markdown]
# <h3><span id="slide-prog1:specdetail">Slide 7/2: Részletesség</span></h3>

# %% [markdown]
# <h4><span id="content-prog1:specdetail">Specifikáció részletessége</span></h4>

# %% [markdown]
# A program főzzön rántottát:
#
# - Á: (konyha)
# - Ef: ( )
# - Uf: (ha a konyha alkalmas ennek elkészítésére, a konyhában legyen egy finom rántotta)
#
# vagy:
#
# - Á: (serpenyő, főzőlap, 3 tojás, olaj, só, fakanál, tányér)
# - Ef: (a serpenyő, tányér és fakanál tiszta, a tojás nem romlott, a főzőlap képes a serpenyőt 200 Celsius fokra felmelegíteni)
# - Uf: (a tojások összekeverve kerültek a 200 fokos serpenyőbe az olaj után, több mint 4 de kevesebb mint 10 percet töltöttek ott, ebből 20 másodpercnél többet nem álltak kavarás nélkül, végül megsózva kikerültek a tányérra)

# %% [markdown]
# <h2><span id="slide-prog1:parts_of_computer">Slide 8: Számítógép alkotóelemei</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:parts_of_computer">Számítógép alkotóelemei</span></h3>

# %% [markdown]
# Hajazva Neumann rendszerezésére:
# - CPU
# - memória
# - háttértár
# - input / output

# %% [markdown]
# <h2><span id="additionallecturecontent-4">Additional content</span></h2>

# %% [markdown]
# <h3><span id="content-prog1:specpairhelp">Specifikáció párosítás jelölés help</span></h3>

# %% [markdown]
# - $\mathbb{B}$ a logikai értékek halmaza.
#     - $l \in \mathbb{B}$ azt jelenti hogy $l$ egy logikai változó
#     - $P: \mathbb{R} \to \mathbb{B}$ pedig azt, hogy $P$ egy valós számból logikai értékbe képző függvény (más néven predikátum)
# - $\mathbb{N}^n$ a $n$ elemű tömböket jelöli amikben $\mathbb{N}$ típusú elemek vannak
#     - $v \in \mathbb{N}^n$ azt jelenti, hogy $v$ egy $n$ elemszámú tömb és mindegyik elem természetes szám, amiket lehet $(v_1,v_2 ... v_n)$-el jelölni
#     - Ha az előző módon kikötöttük micsoda $v$, használhatjuk az $x \in v$ jelölést arra, hogy $v$ egyik eleme $x$ (ez ugye nem alap, mivel $\in$ egy halmazművelet és $v$ nem egy halmaz hanem tömb, de most megengedjük)
